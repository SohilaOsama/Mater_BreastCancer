# %%
import pandas as pd
import numpy as np
import networkx as nx
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors, MACCSkeys
from rdkit.Chem.rdmolops import GetAdjacencyMatrix

# Load dataset
input_csv = 'Kd_data_with_pKd.csv'  # Update with actual path
data = pd.read_csv(input_csv)

if 'canonical_smiles' not in data.columns:
    raise ValueError("The CSV file must contain a 'canonical_smiles' column.")

# Convert SMILES to RDKit Molecule objects
data['molecule'] = data['canonical_smiles'].apply(Chem.MolFromSmiles)
data = data[data['molecule'].notnull()].reset_index(drop=True)  # Remove invalid molecules

# Compute Molecular Descriptors
def calculate_descriptors(mol):
    return pd.Series({
        'MolWt': Descriptors.MolWt(mol),
        'LogP': Descriptors.MolLogP(mol),
        'NumHDonors': Descriptors.NumHDonors(mol),
        'NumHAcceptors': Descriptors.NumHAcceptors(mol),
        'TPSA': Descriptors.TPSA(mol),
        'NumRotatableBonds': Descriptors.NumRotatableBonds(mol),
        'MolMR': Descriptors.MolMR(mol),
        'BalabanJ': Descriptors.BalabanJ(mol),
        'BertzCT': Descriptors.BertzCT(mol),
        'RingCount': Descriptors.RingCount(mol),
        'HallKierAlpha': Descriptors.HallKierAlpha(mol),
        'FractionCSP3': Descriptors.FractionCSP3(mol),
        # 'EState_VSA1': rdMolDescriptors.CalcEStateIndices(mol)[0],
        # 'WienerIndex': Descriptors.WienerIndex(mol)
    })

descriptors_df = data['molecule'].apply(calculate_descriptors)

# Compute 3D Features
def calculate_3D_descriptors(mol):
    try:
        mol_3D = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol_3D, AllChem.ETKDG())
        AllChem.UFFOptimizeMolecule(mol_3D)
        return pd.Series({'MolVolume3D': rdMolDescriptors.CalcExactMolWt(mol_3D)})
    except:
        return pd.Series({'MolVolume3D': np.nan})

features_3D_df = data['molecule'].apply(calculate_3D_descriptors)

# Graph-based Features
def extract_graph_features(mol):
    G = nx.Graph(GetAdjacencyMatrix(mol))
    return {
        "degree_centrality": np.mean(list(nx.degree_centrality(G).values())),
        "closeness_centrality": np.mean(list(nx.closeness_centrality(G).values())),
        "betweenness_centrality": np.mean(list(nx.betweenness_centrality(G).values())),
        "clustering_coefficient": nx.average_clustering(G),
        "graph_density": nx.density(G)
    }

graph_features_df = data['molecule'].apply(extract_graph_features).apply(pd.Series)

# Compute Fingerprints
data['Morgan_Fingerprint'] = data['molecule'].apply(lambda x: AllChem.GetMorganFingerprintAsBitVect(x, 2, nBits=1024))
data['MACCS_Fingerprint'] = data['molecule'].apply(lambda x: MACCSkeys.GenMACCSKeys(x))

# Convert Fingerprints to DataFrame
fingerprints_morgan_df = data['Morgan_Fingerprint'].apply(lambda x: pd.Series(list(map(int, x.ToBitString()))))
fingerprints_maccs_df = data['MACCS_Fingerprint'].apply(lambda x: pd.Series(list(map(int, x.ToBitString()))))

# Combine all extracted features
final_features_df = pd.concat([data, descriptors_df, features_3D_df, graph_features_df], axis=1)
final_fingerprints_df = pd.concat([fingerprints_morgan_df, fingerprints_maccs_df], axis=1)

# Save Outputs
final_features_df.to_csv('Kd_output_with_advanced_features.csv', index=False)
final_fingerprints_df.to_csv('Kd_output_with_extended_fingerprints.csv', index=False)

print("Feature extraction completed successfully.")
# Out:
# [02:31:14] UFFTYPER: Unrecognized charge state for atom: 12
# [02:31:17] UFFTYPER: Unrecognized charge state for atom: 12
# [02:31:17] UFFTYPER: Unrecognized charge state for atom: 12
# [02:31:20] UFFTYPER: Unrecognized charge state for atom: 12
# [02:36:35] UFFTYPER: Unrecognized charge state for atom: 23
# [02:36:35] UFFTYPER: Unrecognized charge state for atom: 23
# [02:40:36] UFFTYPER: Unrecognized charge state for atom: 1
# [02:40:36] UFFTYPER: Unrecognized charge state for atom: 1
# [02:40:42] UFFTYPER: Unrecognized charge state for atom: 1
# [02:40:42] UFFTYPER: Unrecognized charge state for atom: 1
# [02:40:52] UFFTYPER: Unrecognized charge state for atom: 1
# [02:40:52] UFFTYPER: Unrecognized charge state for atom: 1
# [05:32:21] UFFTYPER: Unrecognized charge state for atom: 1
# [05:32:21] UFFTYPER: Unrecognized charge state for atom: 1
# [06:35:27] UFFTYPER: Unrecognized charge state for atom: 1
# [06:35:27] UFFTYPER: Unrecognized charge state for atom: 1
# [06:35:55] UFFTYPER: Unrecognized charge state for atom: 1
# [06:35:55] UFFTYPER: Unrecognized charge state for atom: 1
# [06:36:04] UFFTYPER: Unrecognized charge state for atom: 21
# [06:36:04] UFFTYPER: Unrecognized charge state for atom: 21
# [07:48:48] UFFTYPER: Unrecognized charge state for atom: 1
# [07:48:48] UFFTYPER: Unrecognized charge state for atom: 1
# [07:49:03] UFFTYPER: Unrecognized charge state for atom: 1
# [07:49:03] UFFTYPER: Unrecognized charge state for atom: 1
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# [09:07:18] DEPRECATION WARNING: please use MorganGenerator
# ...
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# [09:07:19] DEPRECATION WARNING: please use MorganGenerator
# Feature extraction completed successfully.

# %%
import pandas as pd

# File paths
features_path = 'Kd_output_with_advanced_features.csv'
fingerprints_path = 'Kd_output_with_extended_fingerprints.csv'

# Load data
features_df = pd.read_csv(features_path)
fingerprints_df = pd.read_csv(fingerprints_path)

# Drop rows with NaN values
features_df_cleaned = features_df.dropna()
fingerprints_df_cleaned = fingerprints_df.dropna()

# Save cleaned data back to CSV
features_df_cleaned.to_csv(features_path, index=False)
fingerprints_df_cleaned.to_csv(fingerprints_path, index=False)

# Print info on removed rows
print(f"Rows removed from {features_path}: {len(features_df) - len(features_df_cleaned)}")
print(f"Rows removed from {fingerprints_path}: {len(fingerprints_df) - len(fingerprints_df_cleaned)}")
# Out:
# Rows removed from Kd_output_with_advanced_features.csv: 65
# Rows removed from Kd_output_with_extended_fingerprints.csv: 0

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import joblib

# Load the dataset
features_path = 'Kd_output_with_advanced_features.csv'
fingerprints_path = 'Kd_output_with_extended_fingerprints.csv'
features_df = pd.read_csv(features_path)
fingerprints_df = pd.read_csv(fingerprints_path)

# Ensure the target column pKd is present
if 'pKd' not in features_df.columns:
    raise ValueError("The features CSV file must contain a 'pKd' column.")

# Combine features and fingerprints
combined_df = pd.concat([features_df, fingerprints_df], axis=1)

# Drop rows with NaN values
combined_df.dropna(inplace=True)

# Feature Selection
features = combined_df.drop(columns=['pKd', 'canonical_smiles', 'molecule', 'Morgan_Fingerprint', 'MACCS_Fingerprint', 'target_pref_name',
                                     'molecule_chembl_id', 'standard_value', 'standard_type', 'target_organism', 'Kd_M'])
target = combined_df['pKd']

# Scale features using RobustScaler (better for outliers)
scaler = RobustScaler()
X_scaled = scaler.fit_transform(features)
y = target.values.reshape(-1, 1)

# Convert to PyTorch tensors
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

# Train-test split
train_size = int(0.8 * len(X_tensor))
test_size = len(X_tensor) - train_size
train_data, test_data = random_split(TensorDataset(X_tensor, y_tensor), [train_size, test_size])

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# Define Neural Network
class AdvancedNN(nn.Module):
    def __init__(self, input_dim):
        super(AdvancedNN, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),

            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(128, 1)  # Output layer
        )

    def forward(self, x):
        return self.model(x)

# Model setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AdvancedNN(input_dim=X_scaled.shape[1]).to(device)

# Loss and Optimizer
criterion = nn.MSELoss()
optimizer = optim.RAdam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

# Training loop
num_epochs = 200
best_loss = float("inf")
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        
        optimizer.zero_grad()
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    scheduler.step()
    
    # Validation
    model.eval()
    test_preds, test_targets = [], []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            preds = model(X_batch)
            test_preds.extend(preds.cpu().numpy())
            test_targets.extend(y_batch.cpu().numpy())

    test_r2 = r2_score(test_targets, test_preds)
    test_mse = mean_squared_error(test_targets, test_preds)

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f} - Test R2: {test_r2:.4f} - Test MSE: {test_mse:.4f}")

    # Save the best model based on test MSE
    if epoch == 0 or test_mse < best_loss:
        best_loss = test_mse
        torch.save(model.state_dict(), "best_advanced_nn.pth")

# Save the scaler
joblib.dump(scaler, "scaler_advanced.joblib")

# Load best model
model.load_state_dict(torch.load("best_advanced_nn.pth"))
model.eval()

# Final evaluation
test_preds, test_targets = [], []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        preds = model(X_batch)
        test_preds.extend(preds.cpu().numpy())
        test_targets.extend(y_batch.cpu().numpy())

final_r2 = r2_score(test_targets, test_preds)
final_mse = mean_squared_error(test_targets, test_preds)

print(f"Final Model R2: {final_r2:.4f}")
print(f"Final Model MSE: {final_mse:.4f}")

# Save final results
final_results = pd.DataFrame({'Actual': test_targets.flatten(), 'Predicted': test_preds.flatten()})
final_results.to_csv("DeepLearning_Predictions_Advanced.csv", index=False)
print("Predictions saved to DeepLearning_Predictions_Advanced.csv")
# Out:
# Epoch 1/200 - Train Loss: 24.2319 - Test R2: -16.6709 - Test MSE: 28.1686
# Epoch 2/200 - Train Loss: 21.6421 - Test R2: -14.6516 - Test MSE: 24.9498
# Epoch 3/200 - Train Loss: 19.2262 - Test R2: -12.9782 - Test MSE: 22.2823
# Epoch 4/200 - Train Loss: 16.8128 - Test R2: -11.8737 - Test MSE: 20.5215
# Epoch 5/200 - Train Loss: 14.7956 - Test R2: -10.8350 - Test MSE: 18.8659
# Epoch 6/200 - Train Loss: 12.9115 - Test R2: -9.6060 - Test MSE: 16.9067
# Epoch 7/200 - Train Loss: 11.6315 - Test R2: -9.1548 - Test MSE: 16.1875
# Epoch 8/200 - Train Loss: 10.8659 - Test R2: -8.8573 - Test MSE: 15.7132
# Epoch 9/200 - Train Loss: 10.3802 - Test R2: -8.3448 - Test MSE: 14.8963
# Epoch 10/200 - Train Loss: 10.0534 - Test R2: -8.4769 - Test MSE: 15.1068
# Epoch 11/200 - Train Loss: 10.0836 - Test R2: -8.5094 - Test MSE: 15.1587
# Epoch 12/200 - Train Loss: 10.0566 - Test R2: -8.4634 - Test MSE: 15.0853
# Epoch 13/200 - Train Loss: 9.8141 - Test R2: -8.2790 - Test MSE: 14.7914
# Epoch 14/200 - Train Loss: 9.2553 - Test R2: -7.4406 - Test MSE: 13.4549
# Epoch 15/200 - Train Loss: 8.2397 - Test R2: -6.7245 - Test MSE: 12.3135
# Epoch 16/200 - Train Loss: 6.9783 - Test R2: -5.4667 - Test MSE: 10.3084
# Epoch 17/200 - Train Loss: 5.3758 - Test R2: -3.9675 - Test MSE: 7.9185
# Epoch 18/200 - Train Loss: 3.8281 - Test R2: -2.5250 - Test MSE: 5.6191
# Epoch 19/200 - Train Loss: 2.7595 - Test R2: -1.3799 - Test MSE: 3.7938
# Epoch 20/200 - Train Loss: 1.9966 - Test R2: -0.7620 - Test MSE: 2.8088
# Epoch 21/200 - Train Loss: 1.5763 - Test R2: -0.2097 - Test MSE: 1.9284
# Epoch 22/200 - Train Loss: 1.4131 - Test R2: -0.1462 - Test MSE: 1.8272
# Epoch 23/200 - Train Loss: 1.3376 - Test R2: -0.0614 - Test MSE: 1.6920
# Epoch 24/200 - Train Loss: 1.2201 - Test R2: -0.0143 - Test MSE: 1.6168
# Epoch 25/200 - Train Loss: 1.1744 - Test R2: 0.0874 - Test MSE: 1.4547
# Epoch 26/200 - Train Loss: 1.1223 - Test R2: 0.0908 - Test MSE: 1.4493
# Epoch 27/200 - Train Loss: 1.0227 - Test R2: 0.1207 - Test MSE: 1.4016
# Epoch 28/200 - Train Loss: 1.0035 - Test R2: 0.1090 - Test MSE: 1.4203
# Epoch 29/200 - Train Loss: 0.9801 - Test R2: 0.1308 - Test MSE: 1.3856
# Epoch 30/200 - Train Loss: 0.9442 - Test R2: 0.1328 - Test MSE: 1.3824
# Epoch 31/200 - Train Loss: 0.9684 - Test R2: 0.1296 - Test MSE: 1.3874
# Epoch 32/200 - Train Loss: 0.9674 - Test R2: 0.1264 - Test MSE: 1.3927
# Epoch 33/200 - Train Loss: 0.9606 - Test R2: 0.1050 - Test MSE: 1.4268
# Epoch 34/200 - Train Loss: 1.0308 - Test R2: 0.1163 - Test MSE: 1.4087
# Epoch 35/200 - Train Loss: 1.0404 - Test R2: 0.1744 - Test MSE: 1.3161
# Epoch 36/200 - Train Loss: 1.1291 - Test R2: 0.1143 - Test MSE: 1.4119
# Epoch 37/200 - Train Loss: 1.0927 - Test R2: 0.0787 - Test MSE: 1.4686
# Epoch 38/200 - Train Loss: 1.1552 - Test R2: 0.0849 - Test MSE: 1.4587
# Epoch 39/200 - Train Loss: 1.1325 - Test R2: 0.1828 - Test MSE: 1.3026
# Epoch 40/200 - Train Loss: 1.0982 - Test R2: 0.0533 - Test MSE: 1.5090
# Epoch 41/200 - Train Loss: 1.1341 - Test R2: 0.0989 - Test MSE: 1.4364
# Epoch 42/200 - Train Loss: 1.1057 - Test R2: 0.0966 - Test MSE: 1.4401
# Epoch 43/200 - Train Loss: 1.1029 - Test R2: 0.0142 - Test MSE: 1.5715
# Epoch 44/200 - Train Loss: 1.0573 - Test R2: 0.0954 - Test MSE: 1.4420
# Epoch 45/200 - Train Loss: 0.9865 - Test R2: 0.1467 - Test MSE: 1.3602
# Epoch 46/200 - Train Loss: 0.9418 - Test R2: 0.1095 - Test MSE: 1.4196
# Epoch 47/200 - Train Loss: 0.9217 - Test R2: 0.1428 - Test MSE: 1.3665
# Epoch 48/200 - Train Loss: 0.8613 - Test R2: 0.1205 - Test MSE: 1.4020
# Epoch 49/200 - Train Loss: 0.8421 - Test R2: 0.1428 - Test MSE: 1.3664
# Epoch 50/200 - Train Loss: 0.8295 - Test R2: 0.1426 - Test MSE: 1.3668
# Epoch 51/200 - Train Loss: 0.8028 - Test R2: 0.1435 - Test MSE: 1.3653
# Epoch 52/200 - Train Loss: 0.7990 - Test R2: 0.1485 - Test MSE: 1.3573
# Epoch 53/200 - Train Loss: 0.8341 - Test R2: 0.1497 - Test MSE: 1.3555
# Epoch 54/200 - Train Loss: 0.8465 - Test R2: 0.1438 - Test MSE: 1.3648
# Epoch 55/200 - Train Loss: 0.8561 - Test R2: 0.1433 - Test MSE: 1.3657
# Epoch 56/200 - Train Loss: 0.8924 - Test R2: 0.1634 - Test MSE: 1.3336
# Epoch 57/200 - Train Loss: 0.8910 - Test R2: 0.0601 - Test MSE: 1.4983
# Epoch 58/200 - Train Loss: 0.9570 - Test R2: -0.0430 - Test MSE: 1.6626
# Epoch 59/200 - Train Loss: 0.9872 - Test R2: 0.0550 - Test MSE: 1.5065
# Epoch 60/200 - Train Loss: 0.9144 - Test R2: 0.0038 - Test MSE: 1.5880
# Epoch 61/200 - Train Loss: 0.9680 - Test R2: 0.0494 - Test MSE: 1.5152
# Epoch 62/200 - Train Loss: 0.9891 - Test R2: 0.1091 - Test MSE: 1.4202
# Epoch 63/200 - Train Loss: 0.9014 - Test R2: 0.0950 - Test MSE: 1.4426
# Epoch 64/200 - Train Loss: 0.8805 - Test R2: 0.1043 - Test MSE: 1.4279
# Epoch 65/200 - Train Loss: 0.8289 - Test R2: 0.1549 - Test MSE: 1.3472
# Epoch 66/200 - Train Loss: 0.8033 - Test R2: 0.1264 - Test MSE: 1.3926
# Epoch 67/200 - Train Loss: 0.7842 - Test R2: 0.0852 - Test MSE: 1.4582
# Epoch 68/200 - Train Loss: 0.7240 - Test R2: 0.1052 - Test MSE: 1.4264
# Epoch 69/200 - Train Loss: 0.7045 - Test R2: 0.0997 - Test MSE: 1.4352
# Epoch 70/200 - Train Loss: 0.6874 - Test R2: 0.1056 - Test MSE: 1.4257
# Epoch 71/200 - Train Loss: 0.7059 - Test R2: 0.0971 - Test MSE: 1.4392
# Epoch 72/200 - Train Loss: 0.7207 - Test R2: 0.1021 - Test MSE: 1.4313
# Epoch 73/200 - Train Loss: 0.6979 - Test R2: 0.1108 - Test MSE: 1.4175
# Epoch 74/200 - Train Loss: 0.6702 - Test R2: 0.0839 - Test MSE: 1.4604
# Epoch 75/200 - Train Loss: 0.7010 - Test R2: 0.0840 - Test MSE: 1.4601
# Epoch 76/200 - Train Loss: 0.7424 - Test R2: 0.1240 - Test MSE: 1.3964
# Epoch 77/200 - Train Loss: 0.7304 - Test R2: 0.1080 - Test MSE: 1.4219
# Epoch 78/200 - Train Loss: 0.7795 - Test R2: 0.0917 - Test MSE: 1.4478
# Epoch 79/200 - Train Loss: 0.8638 - Test R2: 0.0966 - Test MSE: 1.4401
# Epoch 80/200 - Train Loss: 0.8261 - Test R2: -0.0093 - Test MSE: 1.6089
# Epoch 81/200 - Train Loss: 0.8283 - Test R2: 0.1135 - Test MSE: 1.4131
# Epoch 82/200 - Train Loss: 0.8074 - Test R2: 0.0927 - Test MSE: 1.4463
# Epoch 83/200 - Train Loss: 0.7802 - Test R2: 0.0775 - Test MSE: 1.4705
# Epoch 84/200 - Train Loss: 0.7505 - Test R2: 0.0963 - Test MSE: 1.4406
# Epoch 85/200 - Train Loss: 0.7216 - Test R2: 0.1172 - Test MSE: 1.4072
# Epoch 86/200 - Train Loss: 0.7004 - Test R2: 0.0995 - Test MSE: 1.4354
# Epoch 87/200 - Train Loss: 0.6385 - Test R2: 0.0974 - Test MSE: 1.4389
# Epoch 88/200 - Train Loss: 0.6368 - Test R2: 0.0913 - Test MSE: 1.4486
# Epoch 89/200 - Train Loss: 0.6308 - Test R2: 0.1301 - Test MSE: 1.3867
# Epoch 90/200 - Train Loss: 0.6021 - Test R2: 0.1211 - Test MSE: 1.4011
# Epoch 91/200 - Train Loss: 0.6141 - Test R2: 0.1105 - Test MSE: 1.4179
# Epoch 92/200 - Train Loss: 0.5816 - Test R2: 0.1091 - Test MSE: 1.4202
# Epoch 93/200 - Train Loss: 0.6093 - Test R2: 0.1166 - Test MSE: 1.4082
# Epoch 94/200 - Train Loss: 0.5707 - Test R2: 0.0979 - Test MSE: 1.4380
# Epoch 95/200 - Train Loss: 0.5923 - Test R2: 0.0973 - Test MSE: 1.4390
# Epoch 96/200 - Train Loss: 0.6526 - Test R2: 0.0897 - Test MSE: 1.4511
# Epoch 97/200 - Train Loss: 0.6111 - Test R2: 0.1268 - Test MSE: 1.3919
# Epoch 98/200 - Train Loss: 0.7197 - Test R2: 0.1126 - Test MSE: 1.4145
# Epoch 99/200 - Train Loss: 0.7100 - Test R2: 0.0829 - Test MSE: 1.4620
# Epoch 100/200 - Train Loss: 0.7073 - Test R2: 0.0799 - Test MSE: 1.4668
# Epoch 101/200 - Train Loss: 0.7714 - Test R2: -0.0314 - Test MSE: 1.6441
# Epoch 102/200 - Train Loss: 0.7336 - Test R2: 0.0936 - Test MSE: 1.4448
# Epoch 103/200 - Train Loss: 0.6792 - Test R2: 0.0475 - Test MSE: 1.5184
# Epoch 104/200 - Train Loss: 0.6927 - Test R2: 0.1457 - Test MSE: 1.3619
# Epoch 105/200 - Train Loss: 0.6741 - Test R2: 0.1244 - Test MSE: 1.3958
# Epoch 106/200 - Train Loss: 0.6297 - Test R2: 0.0797 - Test MSE: 1.4670
# Epoch 107/200 - Train Loss: 0.5793 - Test R2: 0.1256 - Test MSE: 1.3939
# Epoch 108/200 - Train Loss: 0.5369 - Test R2: 0.1165 - Test MSE: 1.4083
# Epoch 109/200 - Train Loss: 0.5394 - Test R2: 0.1247 - Test MSE: 1.3952
# Epoch 110/200 - Train Loss: 0.5352 - Test R2: 0.1266 - Test MSE: 1.3922
# Epoch 111/200 - Train Loss: 0.5164 - Test R2: 0.1219 - Test MSE: 1.3997
# Epoch 112/200 - Train Loss: 0.5458 - Test R2: 0.1171 - Test MSE: 1.4074
# Epoch 113/200 - Train Loss: 0.5226 - Test R2: 0.1026 - Test MSE: 1.4306
# Epoch 114/200 - Train Loss: 0.4925 - Test R2: 0.1004 - Test MSE: 1.4341
# Epoch 115/200 - Train Loss: 0.5139 - Test R2: 0.0847 - Test MSE: 1.4591
# Epoch 116/200 - Train Loss: 0.5645 - Test R2: 0.1646 - Test MSE: 1.3317
# Epoch 117/200 - Train Loss: 0.6283 - Test R2: 0.0761 - Test MSE: 1.4728
# Epoch 118/200 - Train Loss: 0.6629 - Test R2: 0.0628 - Test MSE: 1.4939
# Epoch 119/200 - Train Loss: 0.6800 - Test R2: -0.0752 - Test MSE: 1.7140
# Epoch 120/200 - Train Loss: 0.6797 - Test R2: 0.1367 - Test MSE: 1.3762
# Epoch 121/200 - Train Loss: 0.6315 - Test R2: -0.0502 - Test MSE: 1.6741
# Epoch 122/200 - Train Loss: 0.6297 - Test R2: 0.0908 - Test MSE: 1.4493
# Epoch 123/200 - Train Loss: 0.6210 - Test R2: 0.0976 - Test MSE: 1.4385
# Epoch 124/200 - Train Loss: 0.6430 - Test R2: 0.1226 - Test MSE: 1.3986
# Epoch 125/200 - Train Loss: 0.5686 - Test R2: 0.0925 - Test MSE: 1.4466
# Epoch 126/200 - Train Loss: 0.5203 - Test R2: 0.0711 - Test MSE: 1.4808
# Epoch 127/200 - Train Loss: 0.5243 - Test R2: 0.0748 - Test MSE: 1.4748
# Epoch 128/200 - Train Loss: 0.4554 - Test R2: 0.0772 - Test MSE: 1.4710
# Epoch 129/200 - Train Loss: 0.4758 - Test R2: 0.0751 - Test MSE: 1.4744
# Epoch 130/200 - Train Loss: 0.4643 - Test R2: 0.0863 - Test MSE: 1.4565
# Epoch 131/200 - Train Loss: 0.4673 - Test R2: 0.0788 - Test MSE: 1.4684
# Epoch 132/200 - Train Loss: 0.4469 - Test R2: 0.0727 - Test MSE: 1.4781
# Epoch 133/200 - Train Loss: 0.4746 - Test R2: 0.0838 - Test MSE: 1.4604
# Epoch 134/200 - Train Loss: 0.4478 - Test R2: 0.0982 - Test MSE: 1.4375
# Epoch 135/200 - Train Loss: 0.4774 - Test R2: 0.0803 - Test MSE: 1.4661
# Epoch 136/200 - Train Loss: 0.4793 - Test R2: 0.0239 - Test MSE: 1.5560
# Epoch 137/200 - Train Loss: 0.5356 - Test R2: 0.0812 - Test MSE: 1.4647
# Epoch 138/200 - Train Loss: 0.5373 - Test R2: 0.0230 - Test MSE: 1.5574
# Epoch 139/200 - Train Loss: 0.5705 - Test R2: 0.0460 - Test MSE: 1.5208
# Epoch 140/200 - Train Loss: 0.6055 - Test R2: 0.0932 - Test MSE: 1.4455
# Epoch 141/200 - Train Loss: 0.5776 - Test R2: 0.0345 - Test MSE: 1.5391
# Epoch 142/200 - Train Loss: 0.6214 - Test R2: -0.0066 - Test MSE: 1.6046
# Epoch 143/200 - Train Loss: 0.6075 - Test R2: 0.0289 - Test MSE: 1.5480
# Epoch 144/200 - Train Loss: 0.5659 - Test R2: 0.0496 - Test MSE: 1.5150
# Epoch 145/200 - Train Loss: 0.5120 - Test R2: 0.0928 - Test MSE: 1.4462
# Epoch 146/200 - Train Loss: 0.5109 - Test R2: 0.0479 - Test MSE: 1.5177
# Epoch 147/200 - Train Loss: 0.4466 - Test R2: 0.0920 - Test MSE: 1.4474
# Epoch 148/200 - Train Loss: 0.4369 - Test R2: 0.0638 - Test MSE: 1.4924
# Epoch 149/200 - Train Loss: 0.4189 - Test R2: 0.0663 - Test MSE: 1.4884
# Epoch 150/200 - Train Loss: 0.4056 - Test R2: 0.0496 - Test MSE: 1.5150
# Epoch 151/200 - Train Loss: 0.4042 - Test R2: 0.0752 - Test MSE: 1.4742
# Epoch 152/200 - Train Loss: 0.4075 - Test R2: 0.0634 - Test MSE: 1.4930
# Epoch 153/200 - Train Loss: 0.4263 - Test R2: 0.0644 - Test MSE: 1.4914
# Epoch 154/200 - Train Loss: 0.4163 - Test R2: 0.0419 - Test MSE: 1.5273
# Epoch 155/200 - Train Loss: 0.4399 - Test R2: 0.0550 - Test MSE: 1.5064
# Epoch 156/200 - Train Loss: 0.4416 - Test R2: 0.0694 - Test MSE: 1.4835
# Epoch 157/200 - Train Loss: 0.4462 - Test R2: 0.0498 - Test MSE: 1.5146
# Epoch 158/200 - Train Loss: 0.5084 - Test R2: 0.0065 - Test MSE: 1.5836
# Epoch 159/200 - Train Loss: 0.5079 - Test R2: -0.0056 - Test MSE: 1.6030
# Epoch 160/200 - Train Loss: 0.5231 - Test R2: 0.1114 - Test MSE: 1.4165
# Epoch 161/200 - Train Loss: 0.5676 - Test R2: 0.0972 - Test MSE: 1.4391
# Epoch 162/200 - Train Loss: 0.5296 - Test R2: 0.0725 - Test MSE: 1.4786
# Epoch 163/200 - Train Loss: 0.5386 - Test R2: -0.0081 - Test MSE: 1.6069
# Epoch 164/200 - Train Loss: 0.5292 - Test R2: 0.0516 - Test MSE: 1.5119
# Epoch 165/200 - Train Loss: 0.4935 - Test R2: 0.1037 - Test MSE: 1.4287
# Epoch 166/200 - Train Loss: 0.4510 - Test R2: 0.1221 - Test MSE: 1.3995
# Epoch 167/200 - Train Loss: 0.4462 - Test R2: 0.1356 - Test MSE: 1.3778
# Epoch 168/200 - Train Loss: 0.3775 - Test R2: 0.0464 - Test MSE: 1.5201
# Epoch 169/200 - Train Loss: 0.3572 - Test R2: 0.1074 - Test MSE: 1.4228
# Epoch 170/200 - Train Loss: 0.3461 - Test R2: 0.0919 - Test MSE: 1.4475
# Epoch 171/200 - Train Loss: 0.3643 - Test R2: 0.1050 - Test MSE: 1.4267
# Epoch 172/200 - Train Loss: 0.3905 - Test R2: 0.0938 - Test MSE: 1.4446
# Epoch 173/200 - Train Loss: 0.3525 - Test R2: 0.1116 - Test MSE: 1.4161
# Epoch 174/200 - Train Loss: 0.3542 - Test R2: 0.1092 - Test MSE: 1.4199
# Epoch 175/200 - Train Loss: 0.4020 - Test R2: 0.0728 - Test MSE: 1.4780
# Epoch 176/200 - Train Loss: 0.3847 - Test R2: 0.0453 - Test MSE: 1.5219
# Epoch 177/200 - Train Loss: 0.4546 - Test R2: -0.0053 - Test MSE: 1.6024
# Epoch 178/200 - Train Loss: 0.4699 - Test R2: 0.0779 - Test MSE: 1.4700
# Epoch 179/200 - Train Loss: 0.4739 - Test R2: 0.0652 - Test MSE: 1.4902
# Epoch 180/200 - Train Loss: 0.4881 - Test R2: 0.0280 - Test MSE: 1.5495
# Epoch 181/200 - Train Loss: 0.5290 - Test R2: -0.0382 - Test MSE: 1.6550
# Epoch 182/200 - Train Loss: 0.5466 - Test R2: 0.0271 - Test MSE: 1.5508
# Epoch 183/200 - Train Loss: 0.5142 - Test R2: 0.0990 - Test MSE: 1.4363
# Epoch 184/200 - Train Loss: 0.4364 - Test R2: 0.0839 - Test MSE: 1.4603
# Epoch 185/200 - Train Loss: 0.4420 - Test R2: 0.0807 - Test MSE: 1.4654
# Epoch 186/200 - Train Loss: 0.4119 - Test R2: 0.0863 - Test MSE: 1.4565
# Epoch 187/200 - Train Loss: 0.3845 - Test R2: 0.0637 - Test MSE: 1.4925
# Epoch 188/200 - Train Loss: 0.3775 - Test R2: 0.1044 - Test MSE: 1.4277
# Epoch 189/200 - Train Loss: 0.3540 - Test R2: 0.0818 - Test MSE: 1.4637
# Epoch 190/200 - Train Loss: 0.3419 - Test R2: 0.1047 - Test MSE: 1.4272
# Epoch 191/200 - Train Loss: 0.3292 - Test R2: 0.0886 - Test MSE: 1.4528
# Epoch 192/200 - Train Loss: 0.3375 - Test R2: 0.0922 - Test MSE: 1.4471
# Epoch 193/200 - Train Loss: 0.3436 - Test R2: 0.0970 - Test MSE: 1.4395
# Epoch 194/200 - Train Loss: 0.3534 - Test R2: 0.0935 - Test MSE: 1.4450
# Epoch 195/200 - Train Loss: 0.3766 - Test R2: 0.0690 - Test MSE: 1.4840
# Epoch 196/200 - Train Loss: 0.3602 - Test R2: 0.0822 - Test MSE: 1.4631
# Epoch 197/200 - Train Loss: 0.3877 - Test R2: 0.0464 - Test MSE: 1.5201
# Epoch 198/200 - Train Loss: 0.4206 - Test R2: 0.0619 - Test MSE: 1.4953
# Epoch 199/200 - Train Loss: 0.4421 - Test R2: -0.0221 - Test MSE: 1.6293
# Epoch 200/200 - Train Loss: 0.4405 - Test R2: 0.0390 - Test MSE: 1.5319
# Final Model R2: 0.1828
# Final Model MSE: 1.3026
# C:\Users\MK\AppData\Local\Temp\ipykernel_13920\2708600858.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_advanced_nn.pth"))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 152
#     149 print(f"Final Model MSE: {final_mse:.4f}")
#     151 # Save final results
# --> 152 final_results = pd.DataFrame({'Actual': test_targets.flatten(), 'Predicted': test_preds.flatten()})
#     153 final_results.to_csv("DeepLearning_Predictions_Advanced.csv", index=False)
#     154 print("Predictions saved to DeepLearning_Predictions_Advanced.csv")
#
# AttributeError: 'list' object has no attribute 'flatten'

# %%
combined_df.columns
# Out:
# Index(['target_pref_name', 'canonical_smiles', 'molecule_chembl_id',
#        'standard_value', 'standard_type', 'target_organism', 'Kd_M', 'pKd',
#        'molecule', 'Morgan_Fingerprint',
#        ...
#        '157.1', '158.1', '159.1', '160.1', '161.1', '162.1', '163.1', '164.1',
#        '165.1', '166.1'],
#       dtype='object', length=1220)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import joblib

# Load the dataset
features_path = 'Kd_output_with_advanced_features.csv'
fingerprints_path = 'Kd_output_with_extended_fingerprints.csv'
features_df = pd.read_csv(features_path)
fingerprints_df = pd.read_csv(fingerprints_path)

# Ensure the target column pKd is present
if 'pKd' not in features_df.columns:
    raise ValueError("The features CSV file must contain a 'pKd' column.")

# Combine features and fingerprints
combined_df = pd.concat([features_df, fingerprints_df], axis=1)

# Drop rows with NaN values
combined_df.dropna(inplace=True)

# Feature Selection
features = combined_df.drop(columns=['pKd', 'canonical_smiles', 'molecule', 'Morgan_Fingerprint', 'MACCS_Fingerprint', 'target_pref_name',
                                     'molecule_chembl_id', 'standard_value', 'standard_type', 'target_organism', 'Kd_M'])
target = combined_df['pKd']

# Scale features using RobustScaler (better for outliers)
scaler = RobustScaler()
X_scaled = scaler.fit_transform(features)
y = target.values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train a RandomForestRegressor model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

train_r2 = r2_score(y_train, y_pred_train)
train_mse = mean_squared_error(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)
test_mse = mean_squared_error(y_test, y_pred_test)

print(f"Train R2: {train_r2:.4f}")
print(f"Train MSE: {train_mse:.4f}")
print(f"Test R2: {test_r2:.4f}")
print(f"Test MSE: {test_mse:.4f}")

# Save the model and scaler
joblib.dump(model, "rf_model.joblib")
joblib.dump(scaler, "scaler.joblib")

# Save final predictions
final_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test})
final_results.to_csv("ML_Predictions.csv", index=False)
print("Predictions saved to ML_Predictions.csv")
# Out:
# Train R2: 0.9129
# Train MSE: 0.1401
# Test R2: 0.4955
# Test MSE: 0.8671
# Predictions saved to ML_Predictions.csv

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import joblib

# Load the dataset
features_path = 'Kd_output_with_advanced_features.csv'
fingerprints_path = 'Kd_output_with_extended_fingerprints.csv'
features_df = pd.read_csv(features_path)
fingerprints_df = pd.read_csv(fingerprints_path)

# Ensure the target column pKd is present
if 'pKd' not in features_df.columns:
    raise ValueError("The features CSV file must contain a 'pKd' column.")

# Combine features and fingerprints
combined_df = pd.concat([features_df, fingerprints_df], axis=1)

# Drop rows with NaN values
combined_df.dropna(inplace=True)

# Feature Selection (Remove non-numeric and unnecessary columns)
drop_cols = ['pKd', 'canonical_smiles', 'molecule', 'Morgan_Fingerprint', 
             'MACCS_Fingerprint', 'target_pref_name', 'molecule_chembl_id', 
             'standard_value', 'standard_type', 'target_organism', 'Kd_M']

features = combined_df.drop(columns=drop_cols, errors='ignore')
target = combined_df['pKd']

# Scale features using RobustScaler
scaler = RobustScaler()
X_scaled = scaler.fit_transform(features)
y = target.values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# ---------------------- Overfitting Fix: Feature Selection ---------------------- #
# Train a baseline RandomForest model to get feature importance
baseline_model = RandomForestRegressor(n_estimators=100, random_state=42)
baseline_model.fit(X_train, y_train)

# Get feature importances
importances = baseline_model.feature_importances_
feature_names = features.columns
sorted_idx = np.argsort(importances)[::-1]

# Select top 20 most important features
top_n = 20  
selected_features = [feature_names[i] for i in sorted_idx[:top_n]]
X_train_selected = X_train[:, sorted_idx[:top_n]]
X_test_selected = X_test[:, sorted_idx[:top_n]]

# ---------------------- Overfitting Fix: Optimized RandomForest ---------------------- #
rf_model = RandomForestRegressor(
    n_estimators=200, max_depth=10, 
    max_features="sqrt", min_samples_split=5, 
    min_samples_leaf=2, random_state=42
)

rf_model.fit(X_train_selected, y_train)
y_pred_train = rf_model.predict(X_train_selected)
y_pred_test = rf_model.predict(X_test_selected)

train_r2 = r2_score(y_train, y_pred_train)
train_mse = mean_squared_error(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)
test_mse = mean_squared_error(y_test, y_pred_test)

print(f"RandomForest Train R2: {train_r2:.4f}, MSE: {train_mse:.4f}")
print(f"RandomForest Test R2: {test_r2:.4f}, MSE: {test_mse:.4f}")

# ---------------------- Overfitting Fix: Cross-Validation ---------------------- #
cv_r2 = cross_val_score(rf_model, X_train_selected, y_train, cv=5, scoring='r2')
print(f"Cross-validated R² scores: {cv_r2}")
print(f"Mean CV R²: {cv_r2.mean():.4f}")

# ---------------------- Alternative Models for Comparison ---------------------- #
# Gradient Boosting Model
gb_model = GradientBoostingRegressor(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
gb_model.fit(X_train_selected, y_train)
y_pred_gb = gb_model.predict(X_test_selected)
print(f"GradientBoosting Test R²: {r2_score(y_test, y_pred_gb):.4f}")

# ElasticNet (Linear Model with Regularization)
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_model.fit(X_train_selected, y_train)
y_pred_elastic = elastic_model.predict(X_test_selected)
print(f"ElasticNet Test R²: {r2_score(y_test, y_pred_elastic):.4f}")

# ---------------------- Save Best Model ---------------------- #
joblib.dump(rf_model, "kdoptimized_rf_model.joblib")
joblib.dump(scaler, "kdscaler.joblib")

# Save final predictions
final_results = pd.DataFrame({'Actual': y_test, 'RF_Predicted': y_pred_test, 
                              'GB_Predicted': y_pred_gb, 'ElasticNet_Predicted': y_pred_elastic})
final_results.to_csv("ML_Predictions.csv", index=False)
print("Predictions saved to ML_Predictions.csv")
# Out:
# RandomForest Train R2: 0.5723, MSE: 0.6877
# RandomForest Test R2: 0.4940, MSE: 0.8696
# Cross-validated R² scores: [0.44155    0.43924761 0.44402884 0.48787995 0.42698111]
# Mean CV R²: 0.4479
# GradientBoosting Test R²: 0.5687
# ElasticNet Test R²: 0.0824
# Predictions saved to ML_Predictions.csv

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import joblib

# Load the dataset
features_path = 'Kd_output_with_advanced_features.csv'
fingerprints_path = 'Kd_output_with_extended_fingerprints.csv'
features_df = pd.read_csv(features_path)
fingerprints_df = pd.read_csv(fingerprints_path)

# Ensure the target column pKd is present
if 'pKd' not in features_df.columns:
    raise ValueError("The features CSV file must contain a 'pKd' column.")

# Combine features and fingerprints
combined_df = pd.concat([features_df, fingerprints_df], axis=1)

# Drop rows with NaN values
combined_df.dropna(inplace=True)

# Feature Selection (Remove non-numeric and unnecessary columns)
drop_cols = ['pKd', 'canonical_smiles', 'molecule', 'Morgan_Fingerprint', 
             'MACCS_Fingerprint', 'target_pref_name', 'molecule_chembl_id', 
             'standard_value', 'standard_type', 'target_organism', 'Kd_M']

features = combined_df.drop(columns=drop_cols, errors='ignore')
target = combined_df['pKd']

# Scale features using RobustScaler
scaler = RobustScaler()
X_scaled = scaler.fit_transform(features)
y = target.values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# ---------------------- Overfitting Fix: Feature Selection ---------------------- #
# Train a baseline RandomForest model to get feature importance
baseline_model = RandomForestRegressor(n_estimators=100, random_state=42)
baseline_model.fit(X_train, y_train)

# Get feature importances
importances = baseline_model.feature_importances_
feature_names = features.columns
sorted_idx = np.argsort(importances)[::-1]

# Select top 20 most important features
top_n = 20  
selected_features = [feature_names[i] for i in sorted_idx[:top_n]]
X_train_selected = X_train[:, sorted_idx[:top_n]]
X_test_selected = X_test[:, sorted_idx[:top_n]]

# ---------------------- Overfitting Fix: Optimized RandomForest ---------------------- #
rf_model = RandomForestRegressor(
    n_estimators=200, max_depth=10, 
    max_features="sqrt", min_samples_split=5, 
    min_samples_leaf=2, random_state=42
)

rf_model.fit(X_train_selected, y_train)
y_pred_train = rf_model.predict(X_train_selected)
y_pred_test = rf_model.predict(X_test_selected)

train_r2 = r2_score(y_train, y_pred_train)
train_mse = mean_squared_error(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)
test_mse = mean_squared_error(y_test, y_pred_test)

print(f"RandomForest Train R2: {train_r2:.4f}, MSE: {train_mse:.4f}")
print(f"RandomForest Test R2: {test_r2:.4f}, MSE: {test_mse:.4f}")

# ---------------------- Overfitting Fix: Cross-Validation ---------------------- #
cv_r2 = cross_val_score(rf_model, X_train_selected, y_train, cv=5, scoring='r2')
print(f"Cross-validated R² scores: {cv_r2}")
print(f"Mean CV R²: {cv_r2.mean():.4f}")

# ---------------------- Alternative Models for Comparison ---------------------- #
# Gradient Boosting Model
gb_model = GradientBoostingRegressor(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
gb_model.fit(X_train_selected, y_train)
y_pred_gb = gb_model.predict(X_test_selected)
print(f"GradientBoosting Test R²: {r2_score(y_test, y_pred_gb):.4f}")

# ElasticNet (Linear Model with Regularization)
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_model.fit(X_train_selected, y_train)
y_pred_elastic = elastic_model.predict(X_test_selected)
print(f"ElasticNet Test R²: {r2_score(y_test, y_pred_elastic):.4f}")

# ---------------------- Save Best Model ---------------------- #
joblib.dump(rf_model, "kdoptimized_rf_model.joblib")
joblib.dump(scaler, "kdscaler.joblib")

# Save final predictions
final_results = pd.DataFrame({'Actual': y_test, 'RF_Predicted': y_pred_test, 
                              'GB_Predicted': y_pred_gb, 'ElasticNet_Predicted': y_pred_elastic})
final_results.to_csv("ML_Predictions.csv", index=False)
print("Predictions saved to ML_Predictions.csv")
# Out:
# RandomForest Train R2: 0.5723, MSE: 0.6877
# RandomForest Test R2: 0.4940, MSE: 0.8696
# Cross-validated R² scores: [0.44155    0.43924761 0.44402884 0.48787995 0.42698111]
# Mean CV R²: 0.4479
# GradientBoosting Test R²: 0.5687
# ElasticNet Test R²: 0.0824
# Predictions saved to ML_Predictions.csv

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import joblib

# Load the dataset
features_path = 'Kd_output_with_advanced_features.csv'
fingerprints_path = 'Kd_output_with_extended_fingerprints.csv'
features_df = pd.read_csv(features_path)
fingerprints_df = pd.read_csv(fingerprints_path)

# Ensure the target column pKd is present
if 'pKd' not in features_df.columns:
    raise ValueError("The features CSV file must contain a 'pKd' column.")

# Combine features and fingerprints
combined_df = pd.concat([features_df, fingerprints_df], axis=1)

# Drop rows with NaN values
combined_df.dropna(inplace=True)

# Feature Selection (Remove non-numeric and unnecessary columns)
drop_cols = ['pKd', 'canonical_smiles', 'molecule', 'Morgan_Fingerprint', 
             'MACCS_Fingerprint', 'target_pref_name', 'molecule_chembl_id', 
             'standard_value', 'standard_type', 'target_organism', 'Kd_M']

features = combined_df.drop(columns=drop_cols, errors='ignore')
target = combined_df['pKd']

# Scale features using RobustScaler
scaler = RobustScaler()
X_scaled = scaler.fit_transform(features)
y = target.values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# ---------------------- Overfitting Fix: Feature Selection ---------------------- #
# Train a baseline RandomForest model to get feature importance
baseline_model = RandomForestRegressor(n_estimators=100, random_state=42)
baseline_model.fit(X_train, y_train)

# Get feature importances
importances = baseline_model.feature_importances_
feature_names = features.columns
sorted_idx = np.argsort(importances)[::-1]

# Select top 20 most important features
top_n = 20  
selected_features = [feature_names[i] for i in sorted_idx[:top_n]]
selected_indices = sorted_idx[:top_n]
X_train_selected = X_train[:, sorted_idx[:top_n]]
X_test_selected = X_test[:, sorted_idx[:top_n]]

# Save the selected feature indices
np.save("selected_feature_indices.npy", selected_indices)

# ---------------------- Overfitting Fix: Optimized RandomForest ---------------------- #
rf_model = RandomForestRegressor(
    n_estimators=200, max_depth=10, 
    max_features="sqrt", min_samples_split=5, 
    min_samples_leaf=2, random_state=42
)

rf_model.fit(X_train_selected, y_train)
y_pred_train = rf_model.predict(X_train_selected)
y_pred_test = rf_model.predict(X_test_selected)

train_r2 = r2_score(y_train, y_pred_train)
train_mse = mean_squared_error(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)
test_mse = mean_squared_error(y_test, y_pred_test)

print(f"RandomForest Train R2: {train_r2:.4f}, MSE: {train_mse:.4f}")
print(f"RandomForest Test R2: {test_r2:.4f}, MSE: {test_mse:.4f}")

# ---------------------- Overfitting Fix: Cross-Validation ---------------------- #
cv_r2 = cross_val_score(rf_model, X_train_selected, y_train, cv=5, scoring='r2')
print(f"Cross-validated R² scores: {cv_r2}")
print(f"Mean CV R²: {cv_r2.mean():.4f}")

# ---------------------- Alternative Models for Comparison ---------------------- #
# Gradient Boosting Model
gb_model = GradientBoostingRegressor(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
gb_model.fit(X_train_selected, y_train)
y_pred_gb = gb_model.predict(X_test_selected)
print(f"GradientBoosting Test R²: {r2_score(y_test, y_pred_gb):.4f}")

# ElasticNet (Linear Model with Regularization)
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_model.fit(X_train_selected, y_train)
y_pred_elastic = elastic_model.predict(X_test_selected)
print(f"ElasticNet Test R²: {r2_score(y_test, y_pred_elastic):.4f}")

# ---------------------- Save Best Model ---------------------- #
joblib.dump(rf_model, "kdoptimized_rf_model.joblib")
joblib.dump(scaler, "kdscaler.joblib")

# Save final predictions
final_results = pd.DataFrame({'Actual': y_test, 'RF_Predicted': y_pred_test, 
                              'GB_Predicted': y_pred_gb, 'ElasticNet_Predicted': y_pred_elastic})
final_results.to_csv("ML_Predictions.csv", index=False)
print("Predictions saved to ML_Predictions.csv")
# Out:
# RandomForest Train R2: 0.5723, MSE: 0.6877
# RandomForest Test R2: 0.4940, MSE: 0.8696
# Cross-validated R² scores: [0.44155    0.43924761 0.44402884 0.48787995 0.42698111]
# Mean CV R²: 0.4479
# GradientBoosting Test R²: 0.5687
# ElasticNet Test R²: 0.0824
# Predictions saved to ML_Predictions.csv
